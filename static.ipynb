# %% [markdown]
# # Data loading and static info

# %%
import pandas as pd

# %%
data = pd.read_csv("y_train_HNMbC27.csv")

# %%
data.head()
# Out:
#    index  Diff_VIX_1d  Diff_VIX_1w  Diff_VIX_2w  Diff_V2X_1d  Diff_V2X_1w  \
# 0      0         0.09         0.91         0.78      -0.4476       0.2496
# 1      1         0.40        -0.01         3.83       2.4391      -0.7112
# 2      2        -1.54         1.86         1.56      -0.3430       2.2993
# 3      3        -0.06        -0.99         3.58      -0.2026      -2.4894
# 4      4         0.14        -0.07         1.69       0.2685       1.3956
#
#    Diff_V2X_2w  Diff_EURUSD_1d  Diff_EURUSD_1w  Diff_EURUSD_2w  ...  \
# 0       1.1221          0.0067         -0.0038         -0.0053  ...
# 1       6.1795         -0.0048          0.0034         -0.0046  ...
# 2       2.3575         -0.0016          0.0039         -0.0088  ...
# 3       2.0213         -0.0099         -0.0212         -0.0409  ...
# 4       3.3027         -0.0059         -0.0352         -0.0420  ...
#
#    Diff_SPX_2w  Diff_SRVIX_1d  Diff_SRVIX_1w  Diff_SRVIX_2w  Diff_CVIX_1d  \
# ...

# %% [markdown]
# # Number of rows

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2024 entries, 0 to 2023
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              2024 non-null   int64
#  1   Diff_VIX_1d        2024 non-null   float64
#  2   Diff_VIX_1w        2024 non-null   float64
#  3   Diff_VIX_2w        2024 non-null   float64
#  4   Diff_V2X_1d        2024 non-null   float64
#  5   Diff_V2X_1w        2024 non-null   float64
#  6   Diff_V2X_2w        2024 non-null   float64
#  7   Diff_EURUSD_1d     2024 non-null   float64
#  8   Diff_EURUSD_1w     2024 non-null   float64
#  9   Diff_EURUSD_2w     2024 non-null   float64
#  10  Diff_EURUSDV1M_1d  2024 non-null   float64
#  11  Diff_EURUSDV1M_1w  2024 non-null   float64
#  12  Diff_EURUSDV1M_2w  2024 non-null   float64
#  13  Diff_USGG10YR_1d   2024 non-null   float64
#  14  Diff_USGG10YR_1w   2024 non-null   float64
# ...

# %%
data.mean()
# Out:
# index                1011.500000
# Diff_VIX_1d            -0.029234
# Diff_VIX_1w            -0.117456
# Diff_VIX_2w            -0.027223
# Diff_V2X_1d            -0.049351
# Diff_V2X_1w             0.010143
# Diff_V2X_2w             0.062605
# Diff_EURUSD_1d         -0.000035
# Diff_EURUSD_1w         -0.000161
# Diff_EURUSD_2w         -0.000520
# Diff_EURUSDV1M_1d       0.001909
# Diff_EURUSDV1M_1w      -0.033681
# Diff_EURUSDV1M_2w      -0.023699
# Diff_USGG10YR_1d        0.001243
# Diff_USGG10YR_1w        0.003761
# Diff_USGG10YR_2w        0.002619
# Diff_USGG2YR_1d         0.000612
# Diff_USGG2YR_1w         0.005569
# Diff_USGG2YR_2w         0.005782
# Diff_GDBR10YR_1d        0.000356
# Diff_GDBR10YR_1w        0.004829
# Diff_GDBR10YR_2w        0.009190
# Diff_GDBR2YR_1d         0.001093
# Diff_GDBR2YR_1w         0.005767
# Diff_GDBR2YR_2w         0.010648
# Diff_SX5E_1d            0.142317
# Diff_SX5E_1w            1.547297
# Diff_SX5E_2w            1.222115
# ...

# %%
data.median()
# Out:
# index                1011.50000
# Diff_VIX_1d             0.07000
# Diff_VIX_1w             0.10000
# Diff_VIX_2w             0.17000
# Diff_V2X_1d             0.03510
# Diff_V2X_1w             0.18240
# Diff_V2X_2w             0.31180
# Diff_EURUSD_1d         -0.00020
# Diff_EURUSD_1w          0.00005
# Diff_EURUSD_2w         -0.00080
# Diff_EURUSDV1M_1d       0.01250
# Diff_EURUSDV1M_1w       0.02250
# Diff_EURUSDV1M_2w       0.09750
# Diff_USGG10YR_1d        0.00000
# Diff_USGG10YR_1w        0.00610
# Diff_USGG10YR_2w        0.00035
# Diff_USGG2YR_1d         0.00000
# Diff_USGG2YR_1w         0.00015
# Diff_USGG2YR_2w         0.00025
# Diff_GDBR10YR_1d        0.00100
# Diff_GDBR10YR_1w        0.00800
# Diff_GDBR10YR_2w        0.01550
# Diff_GDBR2YR_1d         0.00100
# Diff_GDBR2YR_1w         0.00400
# Diff_GDBR2YR_2w         0.00800
# Diff_SX5E_1d           -0.99500
# Diff_SX5E_1w           -7.02500
# Diff_SX5E_2w           -9.53000
# Diff_SPX_1d            -0.86000
# ...
